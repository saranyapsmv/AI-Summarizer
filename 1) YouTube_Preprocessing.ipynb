# %%
# !pip install youtube_transcript_api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: youtube_transcript_api in c:\users\a\appdata\roaming\python\python312\site-packages (1.0.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\a\appdata\roaming\python\python312\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in c:\users\a\appdata\roaming\python\python312\site-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a\appdata\roaming\python\python312\site-packages (from requests->youtube_transcript_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a\appdata\roaming\python\python312\site-packages (from requests->youtube_transcript_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a\appdata\roaming\python\python312\site-packages (from requests->youtube_transcript_api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a\appdata\roaming\python\python312\site-packages (from requests->youtube_transcript_api) (2024.8.30)
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
from IPython.display import YouTubeVideo

# %%
video=input("Enter the link of your YouTube Video: ")

# %%
id_video=video.split("=")[1]
print(id_video)
# Out:
# 9z8ujpPgUjI

# %%
YouTubeVideo(id_video)

# %%
transcript = YouTubeTranscriptApi.get_transcript(id_video)

# %%
transcript
# Out:
# [{'text': '[Music]', 'start': 0.62, 'duration': 3.299},
#  {'text': 'jellyfish can be found all over the',
#   'start': 2.0,
#   'duration': 4.48},
#  {'text': 'world from deep oceans to shallow',
#   'start': 3.919,
#   'duration': 4.321},
#  {'text': 'coastal areas', 'start': 6.48, 'duration': 3.52},
#  {'text': "they've been around for hundreds of",
#   'start': 8.24,
#   'duration': 3.84},
#  {'text': 'millions of years', 'start': 10.0, 'duration': 4.639},
#  {'text': 'boneless brainless and bloodless',
#   'start': 12.08,
#   'duration': 4.48},
#  {'text': 'jellyfish are some of the most diverse',
#   'start': 14.639,
#   'duration': 5.921},
#  {'text': 'and fascinating creatures in the sea',
#   'start': 16.56,
#   'duration': 4.0},
#  {'text': "jellyfish aren't actually fish",
#   'start': 21.279,
#   'duration': 4.961},
#  {'text': 'with thousands of different species in',
#   'start': 24.08,
#   'duration': 4.72},
#  {'text': 'two different biological phyla jellyfish',
#   'start': 26.24,
#   'duration': 4.48},
#  {'text': 'is more of a broad term than anything',
#   'start': 28.8,
#   'duration': 3.279},
#  {'text': 'else', 'start': 30.72, 'duration': 3.76},
#  {'text': 'unlike fish which have backbones',
#   'start': 32.079,
#   'duration': 5.361},
#  {'text': 'jellyfish are invertebrates', 'start': 34.48, 'duration': 4.88},
#  {'text': 'jellyfish got their common name from the',
#   'start': 37.44,
#   'duration': 3.84},
#  {'text': "jelly-like material they're made out of",
#   'start': 39.36,
#   'duration': 4.08},
#  {'text': 'called mesoglia', 'start': 41.28, 'duration': 4.56},
#  {'text': 'in recent years scientists have started',
#   'start': 43.44,
#   'duration': 4.799},
#  {'text': 'using the umbrella term sea jellies to',
#   'start': 45.84,
#   'duration': 5.359},
#  {'text': 'clear up the confusion', 'start': 48.239, 'duration': 6.0},
#  {'text': 'there is an immortal jellyfish', 'start': 51.199, 'duration': 5.2},
#  {'text': 'jellyfish can reproduce sexually by',
#   'start': 54.239,
#   'duration': 4.8},
#  {'text': 'releasing sperm and eggs into the water',
#   'start': 56.399,
#   'duration': 4.96},
#  {'text': 'and reproduce asexually by splitting',
#   'start': 59.039,
#   'duration': 4.16},
#  {'text': 'into two or cloning', 'start': 61.359, 'duration': 4.001},
#  {'text': 'but at least one jellyfish can actually',
#   'start': 63.199,
#   'duration': 5.201},
#  {'text': 'reverse the aging process', 'start': 65.36, 'duration': 5.119},
#  {'text': 'the turatopsis dorniere has earned the',
#   'start': 68.4,
#   'duration': 4.719},
#  {'text': 'moniker the immortal jellyfish for being',
#   'start': 70.479,
#   'duration': 4.481},
#  {'text': 'able to undergo a process called',
#   'start': 73.119,
#   'duration': 4.561},
#  {'text': 'transdifferentiation', 'start': 74.96, 'duration': 4.88},
#  {'text': 'an adult or juvenile under stress',
#   'start': 77.68,
#   'duration': 4.72},
#  {'text': 'instead of dying can revert back to a',
#   'start': 79.84,
#   'duration': 4.8},
#  {'text': 'polyp and begin the life cycle all over',
#   'start': 82.4,
#   'duration': 3.28},
#  {'text': 'again', 'start': 84.64, 'duration': 3.119},
#  {'text': 'it is the only animal in the world that',
#   'start': 85.68,
#   'duration': 4.32},
#  {'text': 'is known to be able to reverse its life',
#   'start': 87.759,
#   'duration': 4.641},
#  {'text': 'cycle', 'start': 90.0, 'duration': 2.4},
#  {'text': 'box jellyfish are the most venomous',
#   'start': 93.04,
#   'duration': 4.88},
#  {'text': 'marine animals in the world', 'start': 94.96, 'duration': 5.119},
#  {'text': 'jellyfish stings are a common fear of',
#   'start': 97.92,
#   'duration': 4.239},
#  {'text': 'beachgoers worldwide and with good',
#   'start': 100.079,
#   'duration': 3.521},
#  {'text': 'reason', 'start': 102.159, 'duration': 4.481},
#  {'text': 'there are an estimated 150 million',
#   'start': 103.6,
#   'duration': 6.32},
#  {'text': 'jellyfish stings reported annually',
#   'start': 106.64,
#   'duration': 4.96},
#  {'text': 'and while not all jellyfish have',
#   'start': 109.92,
#   'duration': 4.64},
#  {'text': 'stingers the australian box jellyfish or',
#   'start': 111.6,
#   'duration': 5.6},
#  {'text': 'chiron x fleckery is considered the most',
#   'start': 114.56,
#   'duration': 5.68},
#  {'text': 'venomous marine animal in the world',
#   'start': 117.2,
#   'duration': 5.68},
#  {'text': 'its deadly tentacles can grow up to 10',
#   'start': 120.24,
#   'duration': 4.0},
#  {'text': 'feet long', 'start': 122.88, 'duration': 3.199},
#  {'text': 'humans and other animals that are',
#   'start': 124.24,
#   'duration': 3.6},
#  {'text': 'unlucky enough to get stung may',
#   'start': 126.079,
#   'duration': 4.561},
#  {'text': 'experience paralysis cardiac arrest and',
#   'start': 127.84,
#   'duration': 7.039},
#  {'text': 'even death within just a few minutes',
#   'start': 130.64,
#   'duration': 6.319},
#  {'text': 'jellyfish are 95', 'start': 134.879, 'duration': 3.36},
#  {'text': 'water', 'start': 136.959, 'duration': 3.36},
#  {'text': 'to put this in perspective the average',
#   'start': 138.239,
#   'duration': 4.561},
#  {'text': 'adult human male is about 60 percent',
#   'start': 140.319,
#   'duration': 4.881},
#  {'text': 'water but jellyfish are much simpler',
#   'start': 142.8,
#   'duration': 5.28},
#  {'text': "than humans they don't have hearts blood",
#   'start': 145.2,
#   'duration': 4.96},
#  {'text': 'brains or bones', 'start': 148.08, 'duration': 4.48},
#  {'text': 'jellyfish do have very basic sensory',
#   'start': 150.16,
#   'duration': 4.799},
#  {'text': 'organs in their bells and tentacles and',
#   'start': 152.56,
#   'duration': 4.64},
#  {'text': 'a simple digestive cavity which serves',
#   'start': 154.959,
#   'duration': 6.0},
#  {'text': 'as a stomach intestine and esophagus',
#   'start': 157.2,
#   'duration': 5.84},
#  {'text': 'if a jellyfish washes up on the beach it',
#   'start': 160.959,
#   'duration': 4.241},
#  {'text': 'will mostly evaporate due to the high',
#   'start': 163.04,
#   'duration': 5.04},
#  {'text': 'water content', 'start': 165.2, 'duration': 2.88},
#  {'text': 'groups of jellyfish are called blooms',
#   'start': 168.72,
#   'duration': 4.4},
#  {'text': 'swarms or smacks', 'start': 171.04, 'duration': 4.4},
#  {'text': 'jellyfish blooms can form quickly and',
#   'start': 173.12,
#   'duration': 3.92},
#  {'text': 'scientists think that the jellies',
#   'start': 175.44,
#   'duration': 4.24},
#  {'text': 'congregate for mating purposes',
#   'start': 177.04,
#   'duration': 5.279},
#  {'text': 'in extreme cases the bloom can be so',
#   'start': 179.68,
#   'duration': 4.479},
#  {'text': 'dense there are more jellyfish than',
#   'start': 182.319,
#   'duration': 4.0},
#  {'text': 'water in a given area', 'start': 184.159, 'duration': 4.481},
#  {'text': 'they can be as small as a cubic meter or',
#   'start': 186.319,
#   'duration': 5.441},
#  {'text': 'cover hundreds of square miles', 'start': 188.64, 'duration': 5.04},
#  {'text': "while these blooms are natural they've",
#   'start': 191.76,
#   'duration': 4.32},
#  {'text': 'caused problems all over the world such',
#   'start': 193.68,
#   'duration': 4.72},
#  {'text': 'as clogging fishing equipment in mexico',
#   'start': 196.08,
#   'duration': 4.56},
#  {'text': 'destroying chinese ships and closing',
#   'start': 198.4,
#   'duration': 5.919},
#  {'text': 'beaches in australia and europe',
#   'start': 200.64,
#   'duration': 5.28},
#  {'text': 'there is still so much to learn about',
#   'start': 204.319,
#   'duration': 4.241},
#  {'text': 'these floating mysterious creatures',
#   'start': 205.92,
#   'duration': 4.48},
#  {'text': 'scientists believe that there may be as',
#   'start': 208.56,
#   'duration': 4.88},
#  {'text': 'many as 300 000 species of jellyfish',
#   'start': 210.4,
#   'duration': 6.1},
#  {'text': "that we haven't yet discovered",
#   'start': 213.44,
#   'duration': 7.069},
#  {'text': '[Music]', 'start': 216.5, 'duration': 4.009},
#  {'text': '[Music]', 'start': 227.36, 'duration': 4.67},
#  {'text': 'you', 'start': 236.319, 'duration': 2.081}]

# %%
doc = ""
for line in transcript:
    doc =doc+ ' ' + line['text']
print(type(doc))
print(doc)
#print(len(result))
# Out:
# <class 'str'>
#  [Music] jellyfish can be found all over the world from deep oceans to shallow coastal areas they've been around for hundreds of millions of years boneless brainless and bloodless jellyfish are some of the most diverse and fascinating creatures in the sea jellyfish aren't actually fish with thousands of different species in two different biological phyla jellyfish is more of a broad term than anything else unlike fish which have backbones jellyfish are invertebrates jellyfish got their common name from the jelly-like material they're made out of called mesoglia in recent years scientists have started using the umbrella term sea jellies to clear up the confusion there is an immortal jellyfish jellyfish can reproduce sexually by releasing sperm and eggs into the water and reproduce asexually by splitting into two or cloning but at least one jellyfish can actually reverse the aging process the turatopsis dorniere has earned the moniker the immortal jellyfish for being able to undergo a process called transdifferentiation an adult or juvenile under stress instead of dying can revert back to a polyp and begin the life cycle all over again it is the only animal in the world that is known to be able to reverse its life cycle box jellyfish are the most venomous marine animals in the world jellyfish stings are a common fear of beachgoers worldwide and with good reason there are an estimated 150 million jellyfish stings reported annually and while not all jellyfish have stingers the australian box jellyfish or chiron x fleckery is considered the most venomous marine animal in the world its deadly tentacles can grow up to 10 feet long humans and other animals that are unlucky enough to get stung may experience paralysis cardiac arrest and even death within just a few minutes jellyfish are 95 water to put this in perspective the average adult human male is about 60 percent water but jellyfish are much simpler than humans they don't have hearts blood brains or bones jellyfish do have very basic sensory organs in their bells and tentacles and a simple digestive cavity which serves as a stomach intestine and esophagus if a jellyfish washes up on the beach it will mostly evaporate due to the high water content groups of jellyfish are called blooms swarms or smacks jellyfish blooms can form quickly and scientists think that the jellies congregate for mating purposes in extreme cases the bloom can be so dense there are more jellyfish than water in a given area they can be as small as a cubic meter or cover hundreds of square miles while these blooms are natural they've caused problems all over the world such as clogging fishing equipment in mexico destroying chinese ships and closing beaches in australia and europe there is still so much to learn about these floating mysterious creatures scientists believe that there may be as many as 300 000 species of jellyfish that we haven't yet discovered [Music] [Music] you

# %%
doc=[]
for line in transcript:
  if "\n" in line['text']:
    x=line['text'].replace("\n"," ")
    doc.append(x)
  else:
    doc.append(line['text'])
print(doc)
# Out:
# ['[Music]', 'jellyfish can be found all over the', 'world from deep oceans to shallow', 'coastal areas', "they've been around for hundreds of", 'millions of years', 'boneless brainless and bloodless', 'jellyfish are some of the most diverse', 'and fascinating creatures in the sea', "jellyfish aren't actually fish", 'with thousands of different species in', 'two different biological phyla jellyfish', 'is more of a broad term than anything', 'else', 'unlike fish which have backbones', 'jellyfish are invertebrates', 'jellyfish got their common name from the', "jelly-like material they're made out of", 'called mesoglia', 'in recent years scientists have started', 'using the umbrella term sea jellies to', 'clear up the confusion', 'there is an immortal jellyfish', 'jellyfish can reproduce sexually by', 'releasing sperm and eggs into the water', 'and reproduce asexually by splitting', 'into two or cloning', 'but at least one jellyfish can actually', 'reverse the aging process', 'the turatopsis dorniere has earned the', 'moniker the immortal jellyfish for being', 'able to undergo a process called', 'transdifferentiation', 'an adult or juvenile under stress', 'instead of dying can revert back to a', 'polyp and begin the life cycle all over', 'again', 'it is the only animal in the world that', 'is known to be able to reverse its life', 'cycle', 'box jellyfish are the most venomous', 'marine animals in the world', 'jellyfish stings are a common fear of', 'beachgoers worldwide and with good', 'reason', 'there are an estimated 150 million', 'jellyfish stings reported annually', 'and while not all jellyfish have', 'stingers the australian box jellyfish or', 'chiron x fleckery is considered the most', 'venomous marine animal in the world', 'its deadly tentacles can grow up to 10', 'feet long', 'humans and other animals that are', 'unlucky enough to get stung may', 'experience paralysis cardiac arrest and', 'even death within just a few minutes', 'jellyfish are 95', 'water', 'to put this in perspective the average', 'adult human male is about 60 percent', 'water but jellyfish are much simpler', "than humans they don't have hearts blood", 'brains or bones', 'jellyfish do have very basic sensory', 'organs in their bells and tentacles and', 'a simple digestive cavity which serves', 'as a stomach intestine and esophagus', 'if a jellyfish washes up on the beach it', 'will mostly evaporate due to the high', 'water content', 'groups of jellyfish are called blooms', 'swarms or smacks', 'jellyfish blooms can form quickly and', 'scientists think that the jellies', 'congregate for mating purposes', 'in extreme cases the bloom can be so', 'dense there are more jellyfish than', 'water in a given area', 'they can be as small as a cubic meter or', 'cover hundreds of square miles', "while these blooms are natural they've", 'caused problems all over the world such', 'as clogging fishing equipment in mexico', 'destroying chinese ships and closing', 'beaches in australia and europe', 'there is still so much to learn about', 'these floating mysterious creatures', 'scientists believe that there may be as', 'many as 300 000 species of jellyfish', "that we haven't yet discovered", '[Music]', '[Music]', 'you']

# %%
paragraph=" ".join(doc)
print(paragraph)
# Out:
# [Music] jellyfish can be found all over the world from deep oceans to shallow coastal areas they've been around for hundreds of millions of years boneless brainless and bloodless jellyfish are some of the most diverse and fascinating creatures in the sea jellyfish aren't actually fish with thousands of different species in two different biological phyla jellyfish is more of a broad term than anything else unlike fish which have backbones jellyfish are invertebrates jellyfish got their common name from the jelly-like material they're made out of called mesoglia in recent years scientists have started using the umbrella term sea jellies to clear up the confusion there is an immortal jellyfish jellyfish can reproduce sexually by releasing sperm and eggs into the water and reproduce asexually by splitting into two or cloning but at least one jellyfish can actually reverse the aging process the turatopsis dorniere has earned the moniker the immortal jellyfish for being able to undergo a process called transdifferentiation an adult or juvenile under stress instead of dying can revert back to a polyp and begin the life cycle all over again it is the only animal in the world that is known to be able to reverse its life cycle box jellyfish are the most venomous marine animals in the world jellyfish stings are a common fear of beachgoers worldwide and with good reason there are an estimated 150 million jellyfish stings reported annually and while not all jellyfish have stingers the australian box jellyfish or chiron x fleckery is considered the most venomous marine animal in the world its deadly tentacles can grow up to 10 feet long humans and other animals that are unlucky enough to get stung may experience paralysis cardiac arrest and even death within just a few minutes jellyfish are 95 water to put this in perspective the average adult human male is about 60 percent water but jellyfish are much simpler than humans they don't have hearts blood brains or bones jellyfish do have very basic sensory organs in their bells and tentacles and a simple digestive cavity which serves as a stomach intestine and esophagus if a jellyfish washes up on the beach it will mostly evaporate due to the high water content groups of jellyfish are called blooms swarms or smacks jellyfish blooms can form quickly and scientists think that the jellies congregate for mating purposes in extreme cases the bloom can be so dense there are more jellyfish than water in a given area they can be as small as a cubic meter or cover hundreds of square miles while these blooms are natural they've caused problems all over the world such as clogging fishing equipment in mexico destroying chinese ships and closing beaches in australia and europe there is still so much to learn about these floating mysterious creatures scientists believe that there may be as many as 300 000 species of jellyfish that we haven't yet discovered [Music] [Music] you
